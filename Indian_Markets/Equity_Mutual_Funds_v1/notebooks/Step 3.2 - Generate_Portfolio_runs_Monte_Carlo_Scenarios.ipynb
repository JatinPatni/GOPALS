# %%
import pandas as pd
import numpy as np
import csv
import os
from tqdm import tqdm

# %%
sim_save_dir = r'../data/simulations/market_scenarios_monte_carlo'
portfolio_run_out_dir = r'../data/simulations/portfolio_simulations_monte_carlo'

# %%
def gen_pf_wts(total_n, n, num_pf_wt_generations):
    final_list = []
    for i in range(num_pf_wt_generations):
        selected_positions = np.random.choice(range(total_n), size = n, replace=False)
        random_weights = np.random.rand(n)
        random_weights /= np.sum(random_weights)
        random_weights = np.round(random_weights,2)
        portfolio_weights = np.zeros(total_n)
        portfolio_weights[selected_positions] = random_weights
        final_list.append(portfolio_weights)

    return final_list

# %%
def write_results_to_csv(fname, year, pf_wts, portfolio_return, portfolio_vol):
    with open(os.path.join(portfolio_run_out_dir, fname+'_'+year+'.csv'), mode='a', newline='') as f:
        writer = csv.writer(f)    
        writer.writerow(np.append(np.append(pf_wts,portfolio_return), portfolio_vol))
    return True

# %%
def generate_portfolio_ret_vol(pf_wts, ret_np, vol_np, corr_np):
    # Assuming every input is np.array
    cov_matrix = np.outer(vol_np, vol_np) * corr_np
    
    portfolio_return = round(np.dot(pf_wts, ret_np),3)
    portfolio_vol = round(np.sqrt(np.dot(pf_wts.T, np.dot(cov_matrix, pf_wts))),3)

    return portfolio_return, portfolio_vol

# %%
file_names = os.listdir(sim_save_dir)

# %%
file_names
# Out:
# ['mc_sim_1000_year_2017_corr_noise_10.csv',
#  'mc_sim_1000_year_2017_ret_noise_50.csv',
#  'mc_sim_1000_year_2017_risk_noise_10.csv',
#  'mc_sim_1001_year_2017_corr_noise_5.csv',
#  'mc_sim_1001_year_2017_ret_noise_50.csv',
#  'mc_sim_1001_year_2017_risk_noise_20.csv',
#  'mc_sim_1002_year_2017_corr_noise_5.csv',
#  'mc_sim_1002_year_2017_ret_noise_50.csv',
#  'mc_sim_1002_year_2017_risk_noise_20.csv',
#  'mc_sim_1003_year_2017_corr_noise_5.csv',
#  'mc_sim_1003_year_2017_ret_noise_50.csv',
#  'mc_sim_1003_year_2017_risk_noise_20.csv',
#  'mc_sim_1004_year_2017_corr_noise_5.csv',
#  'mc_sim_1004_year_2017_ret_noise_50.csv',
#  'mc_sim_1004_year_2017_risk_noise_20.csv',
#  'mc_sim_1005_year_2017_corr_noise_5.csv',
#  'mc_sim_1005_year_2017_ret_noise_50.csv',
#  'mc_sim_1005_year_2017_risk_noise_20.csv',
#  'mc_sim_1006_year_2017_corr_noise_5.csv',
#  'mc_sim_1006_year_2017_ret_noise_50.csv',
#  'mc_sim_1006_year_2017_risk_noise_20.csv',
#  'mc_sim_1007_year_2017_corr_noise_5.csv',
#  'mc_sim_1007_year_2017_ret_noise_50.csv',
#  'mc_sim_1007_year_2017_risk_noise_20.csv',
#  'mc_sim_1008_year_2017_corr_noise_5.csv',
#  'mc_sim_1008_year_2017_ret_noise_50.csv',
#  'mc_sim_1008_year_2017_risk_noise_20.csv',
#  'mc_sim_1009_year_2017_corr_noise_5.csv',
#  'mc_sim_1009_year_2017_ret_noise_50.csv',
#  'mc_sim_1009_year_2017_risk_noise_20.csv',
#  'mc_sim_100_year_2017_corr_noise_5.csv',
#  'mc_sim_100_year_2017_ret_noise_20.csv',
#  'mc_sim_100_year_2017_risk_noise_10.csv',
#  'mc_sim_1010_year_2017_corr_noise_5.csv',
#  'mc_sim_1010_year_2017_ret_noise_50.csv',
#  'mc_sim_1010_year_2017_risk_noise_20.csv',
#  'mc_sim_1011_year_2017_corr_noise_5.csv',
#  'mc_sim_1011_year_2017_ret_noise_50.csv',
#  'mc_sim_1011_year_2017_risk_noise_20.csv',
#  'mc_sim_1012_year_2017_corr_noise_5.csv',
#  'mc_sim_1012_year_2017_ret_noise_50.csv',
#  'mc_sim_1012_year_2017_risk_noise_20.csv',
#  'mc_sim_1013_year_2017_corr_noise_5.csv',
#  'mc_sim_1013_year_2017_ret_noise_50.csv',
#  'mc_sim_1013_year_2017_risk_noise_20.csv',
#  'mc_sim_1014_year_2017_corr_noise_5.csv',
#  'mc_sim_1014_year_2017_ret_noise_50.csv',
#  'mc_sim_1014_year_2017_risk_noise_20.csv',
#  'mc_sim_1015_year_2017_corr_noise_5.csv',
#  'mc_sim_1015_year_2017_ret_noise_50.csv',
#  'mc_sim_1015_year_2017_risk_noise_20.csv',
#  'mc_sim_1016_year_2017_corr_noise_5.csv',
#  'mc_sim_1016_year_2017_ret_noise_50.csv',
#  'mc_sim_1016_year_2017_risk_noise_20.csv',
#  'mc_sim_1017_year_2017_corr_noise_5.csv',
#  'mc_sim_1017_year_2017_ret_noise_50.csv',
#  'mc_sim_1017_year_2017_risk_noise_20.csv',
#  'mc_sim_1018_year_2017_corr_noise_5.csv',
#  'mc_sim_1018_year_2017_ret_noise_50.csv',
#  'mc_sim_1018_year_2017_risk_noise_20.csv',
#  'mc_sim_1019_year_2017_corr_noise_5.csv',
#  'mc_sim_1019_year_2017_ret_noise_50.csv',
#  'mc_sim_1019_year_2017_risk_noise_20.csv',
#  'mc_sim_101_year_2017_corr_noise_10.csv',
#  'mc_sim_101_year_2017_ret_noise_20.csv',
#  'mc_sim_101_year_2017_risk_noise_10.csv',
#  'mc_sim_1020_year_2017_corr_noise_5.csv',
#  'mc_sim_1020_year_2017_ret_noise_50.csv',
#  'mc_sim_1020_year_2017_risk_noise_20.csv',
#  'mc_sim_1021_year_2017_corr_noise_5.csv',
#  'mc_sim_1021_year_2017_ret_noise_50.csv',
#  'mc_sim_1021_year_2017_risk_noise_20.csv',
#  'mc_sim_1022_year_2017_corr_noise_5.csv',
#  'mc_sim_1022_year_2017_ret_noise_50.csv',
#  'mc_sim_1022_year_2017_risk_noise_20.csv',
#  'mc_sim_1023_year_2017_corr_noise_5.csv',
#  'mc_sim_1023_year_2017_ret_noise_50.csv',
#  'mc_sim_1023_year_2017_risk_noise_20.csv',
#  'mc_sim_1024_year_2017_corr_noise_5.csv',
#  'mc_sim_1024_year_2017_ret_noise_50.csv',
#  'mc_sim_1024_year_2017_risk_noise_20.csv',
#  'mc_sim_1025_year_2017_corr_noise_5.csv',
#  'mc_sim_1025_year_2017_ret_noise_50.csv',
#  'mc_sim_1025_year_2017_risk_noise_20.csv',
#  'mc_sim_1026_year_2017_corr_noise_5.csv',
#  'mc_sim_1026_year_2017_ret_noise_50.csv',
#  'mc_sim_1026_year_2017_risk_noise_20.csv',
#  'mc_sim_1027_year_2017_corr_noise_5.csv',
#  'mc_sim_1027_year_2017_ret_noise_50.csv',
#  'mc_sim_1027_year_2017_risk_noise_20.csv',
#  'mc_sim_1028_year_2017_corr_noise_5.csv',
#  'mc_sim_1028_year_2017_ret_noise_50.csv',
#  'mc_sim_1028_year_2017_risk_noise_20.csv',
#  'mc_sim_1029_year_2017_corr_noise_5.csv',
#  'mc_sim_1029_year_2017_ret_noise_50.csv',
#  'mc_sim_1029_year_2017_risk_noise_20.csv',
#  'mc_sim_102_year_2017_corr_noise_10.csv',
#  'mc_sim_102_year_2017_ret_noise_20.csv',
#  'mc_sim_102_year_2017_risk_noise_10.csv',
#  'mc_sim_1030_year_2017_corr_noise_5.csv',
#  'mc_sim_1030_year_2017_ret_noise_50.csv',
#  'mc_sim_1030_year_2017_risk_noise_20.csv',
#  'mc_sim_1031_year_2017_corr_noise_5.csv',
#  'mc_sim_1031_year_2017_ret_noise_50.csv',
#  'mc_sim_1031_year_2017_risk_noise_20.csv',
#  'mc_sim_1032_year_2017_corr_noise_5.csv',
#  'mc_sim_1032_year_2017_ret_noise_50.csv',
#  'mc_sim_1032_year_2017_risk_noise_20.csv',
#  'mc_sim_1033_year_2017_corr_noise_5.csv',
#  'mc_sim_1033_year_2017_ret_noise_50.csv',
#  'mc_sim_1033_year_2017_risk_noise_20.csv',
#  'mc_sim_1034_year_2017_corr_noise_5.csv',
#  'mc_sim_1034_year_2017_ret_noise_50.csv',
#  'mc_sim_1034_year_2017_risk_noise_20.csv',
#  'mc_sim_1035_year_2017_corr_noise_5.csv',
#  'mc_sim_1035_year_2017_ret_noise_50.csv',
#  'mc_sim_1035_year_2017_risk_noise_20.csv',
#  'mc_sim_1036_year_2017_corr_noise_5.csv',
#  'mc_sim_1036_year_2017_ret_noise_50.csv',
#  'mc_sim_1036_year_2017_risk_noise_20.csv',
#  'mc_sim_1037_year_2017_corr_noise_5.csv',
#  'mc_sim_1037_year_2017_ret_noise_50.csv',
#  'mc_sim_1037_year_2017_risk_noise_20.csv',
#  'mc_sim_1038_year_2017_corr_noise_5.csv',
#  'mc_sim_1038_year_2017_ret_noise_50.csv',
#  'mc_sim_1038_year_2017_risk_noise_20.csv',
#  'mc_sim_1039_year_2017_corr_noise_5.csv',
#  'mc_sim_1039_year_2017_ret_noise_50.csv',
#  'mc_sim_1039_year_2017_risk_noise_20.csv',
#  'mc_sim_103_year_2017_corr_noise_10.csv',
#  'mc_sim_103_year_2017_ret_noise_20.csv',
#  'mc_sim_103_year_2017_risk_noise_10.csv',
#  'mc_sim_1040_year_2017_corr_noise_5.csv',
#  'mc_sim_1040_year_2017_ret_noise_50.csv',
#  'mc_sim_1040_year_2017_risk_noise_20.csv',
#  'mc_sim_1041_year_2017_corr_noise_5.csv',
#  'mc_sim_1041_year_2017_ret_noise_50.csv',
#  'mc_sim_1041_year_2017_risk_noise_20.csv',
#  'mc_sim_1042_year_2017_corr_noise_5.csv',
#  'mc_sim_1042_year_2017_ret_noise_50.csv',
#  'mc_sim_1042_year_2017_risk_noise_20.csv',
#  'mc_sim_1043_year_2017_corr_noise_5.csv',
#  'mc_sim_1043_year_2017_ret_noise_50.csv',
#  'mc_sim_1043_year_2017_risk_noise_20.csv',
#  'mc_sim_1044_year_2017_corr_noise_5.csv',
#  'mc_sim_1044_year_2017_ret_noise_50.csv',
#  'mc_sim_1044_year_2017_risk_noise_20.csv',
#  'mc_sim_1045_year_2017_corr_noise_5.csv',
#  'mc_sim_1045_year_2017_ret_noise_50.csv',
#  'mc_sim_1045_year_2017_risk_noise_20.csv',
#  'mc_sim_1046_year_2017_corr_noise_5.csv',
#  'mc_sim_1046_year_2017_ret_noise_50.csv',
#  'mc_sim_1046_year_2017_risk_noise_20.csv',
#  'mc_sim_1047_year_2017_corr_noise_5.csv',
#  'mc_sim_1047_year_2017_ret_noise_50.csv',
#  'mc_sim_1047_year_2017_risk_noise_20.csv',
#  'mc_sim_1048_year_2017_corr_noise_5.csv',
#  'mc_sim_1048_year_2017_ret_noise_50.csv',
#  'mc_sim_1048_year_2017_risk_noise_20.csv',
#  'mc_sim_1049_year_2017_corr_noise_5.csv',
#  'mc_sim_1049_year_2017_ret_noise_50.csv',
#  'mc_sim_1049_year_2017_risk_noise_20.csv',
#  'mc_sim_104_year_2017_corr_noise_10.csv',
#  'mc_sim_104_year_2017_ret_noise_20.csv',
#  'mc_sim_104_year_2017_risk_noise_10.csv',
#  'mc_sim_1050_year_2017_corr_noise_5.csv',
#  'mc_sim_1050_year_2017_ret_noise_50.csv',
#  'mc_sim_1050_year_2017_risk_noise_20.csv',
#  'mc_sim_1051_year_2017_corr_noise_5.csv',
#  'mc_sim_1051_year_2017_ret_noise_50.csv',
#  'mc_sim_1051_year_2017_risk_noise_20.csv',
#  'mc_sim_1052_year_2017_corr_noise_5.csv',
#  'mc_sim_1052_year_2017_ret_noise_50.csv',
#  'mc_sim_1052_year_2017_risk_noise_20.csv',
#  'mc_sim_1053_year_2017_corr_noise_5.csv',
#  'mc_sim_1053_year_2017_ret_noise_50.csv',
#  'mc_sim_1053_year_2017_risk_noise_20.csv',
#  'mc_sim_1054_year_2017_corr_noise_5.csv',
#  'mc_sim_1054_year_2017_ret_noise_50.csv',
#  'mc_sim_1054_year_2017_risk_noise_20.csv',
#  'mc_sim_1055_year_2017_corr_noise_5.csv',
#  'mc_sim_1055_year_2017_ret_noise_50.csv',
#  'mc_sim_1055_year_2017_risk_noise_20.csv',
#  'mc_sim_1056_year_2017_corr_noise_5.csv',
#  'mc_sim_1056_year_2017_ret_noise_50.csv',
#  'mc_sim_1056_year_2017_risk_noise_20.csv',
#  'mc_sim_1057_year_2017_corr_noise_5.csv',
#  'mc_sim_1057_year_2017_ret_noise_50.csv',
#  'mc_sim_1057_year_2017_risk_noise_20.csv',
#  'mc_sim_1058_year_2017_corr_noise_5.csv',
#  'mc_sim_1058_year_2017_ret_noise_50.csv',
#  'mc_sim_1058_year_2017_risk_noise_20.csv',
#  'mc_sim_1059_year_2017_corr_noise_5.csv',
#  'mc_sim_1059_year_2017_ret_noise_50.csv',
#  'mc_sim_1059_year_2017_risk_noise_20.csv',
#  'mc_sim_105_year_2017_corr_noise_10.csv',
#  'mc_sim_105_year_2017_ret_noise_20.csv',
#  'mc_sim_105_year_2017_risk_noise_10.csv',
#  'mc_sim_1060_year_2017_corr_noise_5.csv',
#  'mc_sim_1060_year_2017_ret_noise_50.csv',
#  'mc_sim_1060_year_2017_risk_noise_20.csv',
#  'mc_sim_1061_year_2017_corr_noise_5.csv',
#  'mc_sim_1061_year_2017_ret_noise_50.csv',
#  'mc_sim_1061_year_2017_risk_noise_20.csv',
#  'mc_sim_1062_year_2017_corr_noise_5.csv',
#  'mc_sim_1062_year_2017_ret_noise_50.csv',
#  'mc_sim_1062_year_2017_risk_noise_20.csv',
#  'mc_sim_1063_year_2017_corr_noise_5.csv',
#  'mc_sim_1063_year_2017_ret_noise_50.csv',
#  'mc_sim_1063_year_2017_risk_noise_20.csv',
#  'mc_sim_1064_year_2017_corr_noise_5.csv',
#  'mc_sim_1064_year_2017_ret_noise_50.csv',
#  'mc_sim_1064_year_2017_risk_noise_20.csv',
#  'mc_sim_1065_year_2017_corr_noise_5.csv',
#  'mc_sim_1065_year_2017_ret_noise_50.csv',
#  'mc_sim_1065_year_2017_risk_noise_20.csv',
#  'mc_sim_1066_year_2017_corr_noise_5.csv',
#  'mc_sim_1066_year_2017_ret_noise_50.csv',
#  'mc_sim_1066_year_2017_risk_noise_20.csv',
#  'mc_sim_1067_year_2017_corr_noise_5.csv',
#  'mc_sim_1067_year_2017_ret_noise_50.csv',
#  'mc_sim_1067_year_2017_risk_noise_20.csv',
#  'mc_sim_1068_year_2017_corr_noise_5.csv',
#  'mc_sim_1068_year_2017_ret_noise_50.csv',
#  'mc_sim_1068_year_2017_risk_noise_20.csv',
#  'mc_sim_1069_year_2017_corr_noise_5.csv',
#  'mc_sim_1069_year_2017_ret_noise_50.csv',
#  'mc_sim_1069_year_2017_risk_noise_20.csv',
#  'mc_sim_106_year_2017_corr_noise_10.csv',
#  'mc_sim_106_year_2017_ret_noise_20.csv',
#  'mc_sim_106_year_2017_risk_noise_10.csv',
#  'mc_sim_1070_year_2017_corr_noise_5.csv',
#  'mc_sim_1070_year_2017_ret_noise_50.csv',
#  'mc_sim_1070_year_2017_risk_noise_20.csv',
#  'mc_sim_1071_year_2017_corr_noise_5.csv',
#  'mc_sim_1071_year_2017_ret_noise_50.csv',
#  'mc_sim_1071_year_2017_risk_noise_20.csv',
#  'mc_sim_1072_year_2017_corr_noise_5.csv',
#  'mc_sim_1072_year_2017_ret_noise_50.csv',
#  'mc_sim_1072_year_2017_risk_noise_20.csv',
#  'mc_sim_1073_year_2017_corr_noise_5.csv',
#  'mc_sim_1073_year_2017_ret_noise_50.csv',
#  'mc_sim_1073_year_2017_risk_noise_20.csv',
#  'mc_sim_1074_year_2017_corr_noise_5.csv',
#  'mc_sim_1074_year_2017_ret_noise_50.csv',
#  'mc_sim_1074_year_2017_risk_noise_20.csv',
#  'mc_sim_1075_year_2017_corr_noise_5.csv',
#  'mc_sim_1075_year_2017_ret_noise_50.csv',
#  'mc_sim_1075_year_2017_risk_noise_20.csv',
#  'mc_sim_1076_year_2017_corr_noise_5.csv',
#  'mc_sim_1076_year_2017_ret_noise_50.csv',
#  'mc_sim_1076_year_2017_risk_noise_20.csv',
#  'mc_sim_1077_year_2017_corr_noise_5.csv',
#  'mc_sim_1077_year_2017_ret_noise_50.csv',
#  'mc_sim_1077_year_2017_risk_noise_20.csv',
#  'mc_sim_1078_year_2017_corr_noise_5.csv',
#  'mc_sim_1078_year_2017_ret_noise_50.csv',
#  'mc_sim_1078_year_2017_risk_noise_20.csv',
#  'mc_sim_1079_year_2017_corr_noise_5.csv',
#  'mc_sim_1079_year_2017_ret_noise_50.csv',
#  'mc_sim_1079_year_2017_risk_noise_20.csv',
#  'mc_sim_107_year_2017_corr_noise_10.csv',
#  'mc_sim_107_year_2017_ret_noise_20.csv',
#  'mc_sim_107_year_2017_risk_noise_10.csv',
#  'mc_sim_1080_year_2017_corr_noise_5.csv',
#  'mc_sim_1080_year_2017_ret_noise_50.csv',
#  'mc_sim_1080_year_2017_risk_noise_20.csv',
#  'mc_sim_1081_year_2017_corr_noise_5.csv',
#  'mc_sim_1081_year_2017_ret_noise_50.csv',
#  'mc_sim_1081_year_2017_risk_noise_20.csv',
#  'mc_sim_1082_year_2017_corr_noise_5.csv',
#  'mc_sim_1082_year_2017_ret_noise_50.csv',
#  'mc_sim_1082_year_2017_risk_noise_20.csv',
#  'mc_sim_1083_year_2017_corr_noise_5.csv',
#  'mc_sim_1083_year_2017_ret_noise_50.csv',
#  'mc_sim_1083_year_2017_risk_noise_20.csv',
#  'mc_sim_1084_year_2017_corr_noise_5.csv',
#  'mc_sim_1084_year_2017_ret_noise_50.csv',
#  'mc_sim_1084_year_2017_risk_noise_20.csv',
#  'mc_sim_1085_year_2017_corr_noise_5.csv',
#  'mc_sim_1085_year_2017_ret_noise_50.csv',
#  'mc_sim_1085_year_2017_risk_noise_20.csv',
#  'mc_sim_1086_year_2017_corr_noise_5.csv',
#  'mc_sim_1086_year_2017_ret_noise_50.csv',
#  'mc_sim_1086_year_2017_risk_noise_20.csv',
#  'mc_sim_1087_year_2017_corr_noise_5.csv',
#  'mc_sim_1087_year_2017_ret_noise_50.csv',
#  'mc_sim_1087_year_2017_risk_noise_20.csv',
#  'mc_sim_1088_year_2017_corr_noise_5.csv',
#  'mc_sim_1088_year_2017_ret_noise_50.csv',
#  'mc_sim_1088_year_2017_risk_noise_20.csv',
#  'mc_sim_1089_year_2017_corr_noise_5.csv',
#  'mc_sim_1089_year_2017_ret_noise_50.csv',
#  'mc_sim_1089_year_2017_risk_noise_20.csv',
#  'mc_sim_108_year_2017_corr_noise_10.csv',
#  'mc_sim_108_year_2017_ret_noise_20.csv',
#  'mc_sim_108_year_2017_risk_noise_10.csv',
#  'mc_sim_1090_year_2017_corr_noise_5.csv',
#  'mc_sim_1090_year_2017_ret_noise_50.csv',
#  'mc_sim_1090_year_2017_risk_noise_20.csv',
#  'mc_sim_1091_year_2017_corr_noise_5.csv',
#  'mc_sim_1091_year_2017_ret_noise_50.csv',
#  'mc_sim_1091_year_2017_risk_noise_20.csv',
#  'mc_sim_1092_year_2017_corr_noise_5.csv',
#  'mc_sim_1092_year_2017_ret_noise_50.csv',
#  'mc_sim_1092_year_2017_risk_noise_20.csv',
#  'mc_sim_1093_year_2017_corr_noise_5.csv',
#  'mc_sim_1093_year_2017_ret_noise_50.csv',
#  'mc_sim_1093_year_2017_risk_noise_20.csv',
#  'mc_sim_1094_year_2017_corr_noise_5.csv',
#  'mc_sim_1094_year_2017_ret_noise_50.csv',
#  'mc_sim_1094_year_2017_risk_noise_20.csv',
#  'mc_sim_1095_year_2017_corr_noise_5.csv',
#  'mc_sim_1095_year_2017_ret_noise_50.csv',
#  'mc_sim_1095_year_2017_risk_noise_20.csv',
#  'mc_sim_1096_year_2017_corr_noise_5.csv',
#  'mc_sim_1096_year_2017_ret_noise_50.csv',
#  'mc_sim_1096_year_2017_risk_noise_20.csv',
#  'mc_sim_1097_year_2017_corr_noise_5.csv',
#  'mc_sim_1097_year_2017_ret_noise_50.csv',
#  'mc_sim_1097_year_2017_risk_noise_20.csv',
#  'mc_sim_1098_year_2017_corr_noise_5.csv',
#  'mc_sim_1098_year_2017_ret_noise_50.csv',
#  'mc_sim_1098_year_2017_risk_noise_20.csv',
#  'mc_sim_1099_year_2017_corr_noise_5.csv',
#  'mc_sim_1099_year_2017_ret_noise_50.csv',
#  'mc_sim_1099_year_2017_risk_noise_20.csv',
#  'mc_sim_109_year_2017_corr_noise_10.csv',
#  'mc_sim_109_year_2017_ret_noise_20.csv',
#  'mc_sim_109_year_2017_risk_noise_10.csv',
#  'mc_sim_10_year_2017_corr_noise_5.csv',
#  'mc_sim_10_year_2017_ret_noise_20.csv',
#  'mc_sim_10_year_2017_risk_noise_10.csv',
#  'mc_sim_1100_year_2017_corr_noise_5.csv',
#  'mc_sim_1100_year_2017_ret_noise_50.csv',
#  'mc_sim_1100_year_2017_risk_noise_20.csv',
#  'mc_sim_1101_year_2017_corr_noise_10.csv',
#  'mc_sim_1101_year_2017_ret_noise_50.csv',
#  'mc_sim_1101_year_2017_risk_noise_20.csv',
#  'mc_sim_1102_year_2017_corr_noise_10.csv',
#  'mc_sim_1102_year_2017_ret_noise_50.csv',
#  'mc_sim_1102_year_2017_risk_noise_20.csv',
#  'mc_sim_1103_year_2017_corr_noise_10.csv',
#  'mc_sim_1103_year_2017_ret_noise_50.csv',
#  'mc_sim_1103_year_2017_risk_noise_20.csv',
#  'mc_sim_1104_year_2017_corr_noise_10.csv',
#  'mc_sim_1104_year_2017_ret_noise_50.csv',
#  'mc_sim_1104_year_2017_risk_noise_20.csv',
#  'mc_sim_1105_year_2017_corr_noise_10.csv',
#  'mc_sim_1105_year_2017_ret_noise_50.csv',
#  'mc_sim_1105_year_2017_risk_noise_20.csv',
#  'mc_sim_1106_year_2017_corr_noise_10.csv',
#  'mc_sim_1106_year_2017_ret_noise_50.csv',
#  'mc_sim_1106_year_2017_risk_noise_20.csv',
#  'mc_sim_1107_year_2017_corr_noise_10.csv',
#  'mc_sim_1107_year_2017_ret_noise_50.csv',
#  'mc_sim_1107_year_2017_risk_noise_20.csv',
#  'mc_sim_1108_year_2017_corr_noise_10.csv',
#  'mc_sim_1108_year_2017_ret_noise_50.csv',
#  'mc_sim_1108_year_2017_risk_noise_20.csv',
#  'mc_sim_1109_year_2017_corr_noise_10.csv',
#  'mc_sim_1109_year_2017_ret_noise_50.csv',
#  'mc_sim_1109_year_2017_risk_noise_20.csv',
#  'mc_sim_110_year_2017_corr_noise_10.csv',
#  'mc_sim_110_year_2017_ret_noise_20.csv',
#  'mc_sim_110_year_2017_risk_noise_10.csv',
#  'mc_sim_1110_year_2017_corr_noise_10.csv',
#  'mc_sim_1110_year_2017_ret_noise_50.csv',
#  'mc_sim_1110_year_2017_risk_noise_20.csv',
#  'mc_sim_1111_year_2017_corr_noise_10.csv',
#  'mc_sim_1111_year_2017_ret_noise_50.csv',
#  'mc_sim_1111_year_2017_risk_noise_20.csv',
#  'mc_sim_1112_year_2017_corr_noise_10.csv',
#  'mc_sim_1112_year_2017_ret_noise_50.csv',
#  'mc_sim_1112_year_2017_risk_noise_20.csv',
#  'mc_sim_1113_year_2017_corr_noise_10.csv',
#  'mc_sim_1113_year_2017_ret_noise_50.csv',
#  'mc_sim_1113_year_2017_risk_noise_20.csv',
#  'mc_sim_1114_year_2017_corr_noise_10.csv',
#  'mc_sim_1114_year_2017_ret_noise_50.csv',
#  'mc_sim_1114_year_2017_risk_noise_20.csv',
#  'mc_sim_1115_year_2017_corr_noise_10.csv',
#  'mc_sim_1115_year_2017_ret_noise_50.csv',
#  'mc_sim_1115_year_2017_risk_noise_20.csv',
#  'mc_sim_1116_year_2017_corr_noise_10.csv',
#  'mc_sim_1116_year_2017_ret_noise_50.csv',
#  'mc_sim_1116_year_2017_risk_noise_20.csv',
#  'mc_sim_1117_year_2017_corr_noise_10.csv',
#  'mc_sim_1117_year_2017_ret_noise_50.csv',
#  'mc_sim_1117_year_2017_risk_noise_20.csv',
#  'mc_sim_1118_year_2017_corr_noise_10.csv',
#  'mc_sim_1118_year_2017_ret_noise_50.csv',
#  'mc_sim_1118_year_2017_risk_noise_20.csv',
#  'mc_sim_1119_year_2017_corr_noise_10.csv',
#  'mc_sim_1119_year_2017_ret_noise_50.csv',
#  'mc_sim_1119_year_2017_risk_noise_20.csv',
#  'mc_sim_111_year_2017_corr_noise_10.csv',
#  'mc_sim_111_year_2017_ret_noise_20.csv',
#  'mc_sim_111_year_2017_risk_noise_10.csv',
#  'mc_sim_1120_year_2017_corr_noise_10.csv',
#  'mc_sim_1120_year_2017_ret_noise_50.csv',
#  'mc_sim_1120_year_2017_risk_noise_20.csv',
#  'mc_sim_1121_year_2017_corr_noise_10.csv',
#  'mc_sim_1121_year_2017_ret_noise_50.csv',
#  'mc_sim_1121_year_2017_risk_noise_20.csv',
#  'mc_sim_1122_year_2017_corr_noise_10.csv',
#  'mc_sim_1122_year_2017_ret_noise_50.csv',
#  'mc_sim_1122_year_2017_risk_noise_20.csv',
#  'mc_sim_1123_year_2017_corr_noise_10.csv',
#  'mc_sim_1123_year_2017_ret_noise_50.csv',
#  'mc_sim_1123_year_2017_risk_noise_20.csv',
#  'mc_sim_1124_year_2017_corr_noise_10.csv',
#  'mc_sim_1124_year_2017_ret_noise_50.csv',
#  'mc_sim_1124_year_2017_risk_noise_20.csv',
#  'mc_sim_1125_year_2017_corr_noise_10.csv',
#  'mc_sim_1125_year_2017_ret_noise_50.csv',
#  'mc_sim_1125_year_2017_risk_noise_20.csv',
#  'mc_sim_1126_year_2017_corr_noise_10.csv',
#  'mc_sim_1126_year_2017_ret_noise_50.csv',
#  'mc_sim_1126_year_2017_risk_noise_20.csv',
#  'mc_sim_1127_year_2017_corr_noise_10.csv',
#  'mc_sim_1127_year_2017_ret_noise_50.csv',
#  'mc_sim_1127_year_2017_risk_noise_20.csv',
#  'mc_sim_1128_year_2017_corr_noise_10.csv',
#  'mc_sim_1128_year_2017_ret_noise_50.csv',
#  'mc_sim_1128_year_2017_risk_noise_20.csv',
#  'mc_sim_1129_year_2017_corr_noise_10.csv',
#  'mc_sim_1129_year_2017_ret_noise_50.csv',
#  'mc_sim_1129_year_2017_risk_noise_20.csv',
#  'mc_sim_112_year_2017_corr_noise_10.csv',
#  'mc_sim_112_year_2017_ret_noise_20.csv',
#  'mc_sim_112_year_2017_risk_noise_10.csv',
#  'mc_sim_1130_year_2017_corr_noise_10.csv',
#  'mc_sim_1130_year_2017_ret_noise_50.csv',
#  'mc_sim_1130_year_2017_risk_noise_20.csv',
#  'mc_sim_1131_year_2017_corr_noise_10.csv',
#  'mc_sim_1131_year_2017_ret_noise_50.csv',
#  'mc_sim_1131_year_2017_risk_noise_20.csv',
#  'mc_sim_1132_year_2017_corr_noise_10.csv',
#  'mc_sim_1132_year_2017_ret_noise_50.csv',
#  'mc_sim_1132_year_2017_risk_noise_20.csv',
#  'mc_sim_1133_year_2017_corr_noise_10.csv',
#  'mc_sim_1133_year_2017_ret_noise_50.csv',
#  'mc_sim_1133_year_2017_risk_noise_20.csv',
#  'mc_sim_1134_year_2017_corr_noise_10.csv',
#  'mc_sim_1134_year_2017_ret_noise_50.csv',
#  'mc_sim_1134_year_2017_risk_noise_20.csv',
#  'mc_sim_1135_year_2017_corr_noise_10.csv',
#  'mc_sim_1135_year_2017_ret_noise_50.csv',
#  'mc_sim_1135_year_2017_risk_noise_20.csv',
#  'mc_sim_1136_year_2017_corr_noise_10.csv',
#  'mc_sim_1136_year_2017_ret_noise_50.csv',
#  'mc_sim_1136_year_2017_risk_noise_20.csv',
#  'mc_sim_1137_year_2017_corr_noise_10.csv',
#  'mc_sim_1137_year_2017_ret_noise_50.csv',
#  'mc_sim_1137_year_2017_risk_noise_20.csv',
#  'mc_sim_1138_year_2017_corr_noise_10.csv',
#  'mc_sim_1138_year_2017_ret_noise_50.csv',
#  'mc_sim_1138_year_2017_risk_noise_20.csv',
#  'mc_sim_1139_year_2017_corr_noise_10.csv',
#  'mc_sim_1139_year_2017_ret_noise_50.csv',
#  'mc_sim_1139_year_2017_risk_noise_20.csv',
#  'mc_sim_113_year_2017_corr_noise_10.csv',
#  'mc_sim_113_year_2017_ret_noise_20.csv',
#  'mc_sim_113_year_2017_risk_noise_10.csv',
#  'mc_sim_1140_year_2017_corr_noise_10.csv',
#  'mc_sim_1140_year_2017_ret_noise_50.csv',
#  'mc_sim_1140_year_2017_risk_noise_20.csv',
#  'mc_sim_1141_year_2017_corr_noise_10.csv',
#  'mc_sim_1141_year_2017_ret_noise_50.csv',
#  'mc_sim_1141_year_2017_risk_noise_20.csv',
#  'mc_sim_1142_year_2017_corr_noise_10.csv',
#  'mc_sim_1142_year_2017_ret_noise_50.csv',
#  'mc_sim_1142_year_2017_risk_noise_20.csv',
#  'mc_sim_1143_year_2017_corr_noise_10.csv',
#  'mc_sim_1143_year_2017_ret_noise_50.csv',
#  'mc_sim_1143_year_2017_risk_noise_20.csv',
#  'mc_sim_1144_year_2017_corr_noise_10.csv',
#  'mc_sim_1144_year_2017_ret_noise_50.csv',
#  'mc_sim_1144_year_2017_risk_noise_20.csv',
#  'mc_sim_1145_year_2017_corr_noise_10.csv',
#  'mc_sim_1145_year_2017_ret_noise_50.csv',
#  'mc_sim_1145_year_2017_risk_noise_20.csv',
#  'mc_sim_1146_year_2017_corr_noise_10.csv',
#  'mc_sim_1146_year_2017_ret_noise_50.csv',
#  'mc_sim_1146_year_2017_risk_noise_20.csv',
#  'mc_sim_1147_year_2017_corr_noise_10.csv',
#  'mc_sim_1147_year_2017_ret_noise_50.csv',
#  'mc_sim_1147_year_2017_risk_noise_20.csv',
#  'mc_sim_1148_year_2017_corr_noise_10.csv',
#  'mc_sim_1148_year_2017_ret_noise_50.csv',
#  'mc_sim_1148_year_2017_risk_noise_20.csv',
#  'mc_sim_1149_year_2017_corr_noise_10.csv',
#  'mc_sim_1149_year_2017_ret_noise_50.csv',
#  'mc_sim_1149_year_2017_risk_noise_20.csv',
#  'mc_sim_114_year_2017_corr_noise_10.csv',
#  'mc_sim_114_year_2017_ret_noise_20.csv',
#  'mc_sim_114_year_2017_risk_noise_10.csv',
#  'mc_sim_1150_year_2017_corr_noise_10.csv',
#  'mc_sim_1150_year_2017_ret_noise_50.csv',
#  'mc_sim_1150_year_2017_risk_noise_20.csv',
#  'mc_sim_1151_year_2017_corr_noise_10.csv',
#  'mc_sim_1151_year_2017_ret_noise_50.csv',
#  'mc_sim_1151_year_2017_risk_noise_20.csv',
#  'mc_sim_1152_year_2017_corr_noise_10.csv',
#  'mc_sim_1152_year_2017_ret_noise_50.csv',
#  'mc_sim_1152_year_2017_risk_noise_20.csv',
#  'mc_sim_1153_year_2017_corr_noise_10.csv',
#  'mc_sim_1153_year_2017_ret_noise_50.csv',
#  'mc_sim_1153_year_2017_risk_noise_20.csv',
#  'mc_sim_1154_year_2017_corr_noise_10.csv',
#  'mc_sim_1154_year_2017_ret_noise_50.csv',
#  'mc_sim_1154_year_2017_risk_noise_20.csv',
#  'mc_sim_1155_year_2017_corr_noise_10.csv',
#  'mc_sim_1155_year_2017_ret_noise_50.csv',
#  'mc_sim_1155_year_2017_risk_noise_20.csv',
#  'mc_sim_1156_year_2017_corr_noise_10.csv',
#  'mc_sim_1156_year_2017_ret_noise_50.csv',
#  'mc_sim_1156_year_2017_risk_noise_20.csv',
#  'mc_sim_1157_year_2017_corr_noise_10.csv',
#  'mc_sim_1157_year_2017_ret_noise_50.csv',
#  'mc_sim_1157_year_2017_risk_noise_20.csv',
#  'mc_sim_1158_year_2017_corr_noise_10.csv',
#  'mc_sim_1158_year_2017_ret_noise_50.csv',
#  'mc_sim_1158_year_2017_risk_noise_20.csv',
#  'mc_sim_1159_year_2017_corr_noise_10.csv',
#  'mc_sim_1159_year_2017_ret_noise_50.csv',
#  'mc_sim_1159_year_2017_risk_noise_20.csv',
#  'mc_sim_115_year_2017_corr_noise_10.csv',
#  'mc_sim_115_year_2017_ret_noise_20.csv',
#  'mc_sim_115_year_2017_risk_noise_10.csv',
#  'mc_sim_1160_year_2017_corr_noise_10.csv',
#  'mc_sim_1160_year_2017_ret_noise_50.csv',
#  'mc_sim_1160_year_2017_risk_noise_20.csv',
#  'mc_sim_1161_year_2017_corr_noise_10.csv',
#  'mc_sim_1161_year_2017_ret_noise_50.csv',
#  'mc_sim_1161_year_2017_risk_noise_20.csv',
#  'mc_sim_1162_year_2017_corr_noise_10.csv',
#  'mc_sim_1162_year_2017_ret_noise_50.csv',
#  'mc_sim_1162_year_2017_risk_noise_20.csv',
#  'mc_sim_1163_year_2017_corr_noise_10.csv',
#  'mc_sim_1163_year_2017_ret_noise_50.csv',
#  'mc_sim_1163_year_2017_risk_noise_20.csv',
#  'mc_sim_1164_year_2017_corr_noise_10.csv',
#  'mc_sim_1164_year_2017_ret_noise_50.csv',
#  'mc_sim_1164_year_2017_risk_noise_20.csv',
#  'mc_sim_1165_year_2017_corr_noise_10.csv',
#  'mc_sim_1165_year_2017_ret_noise_50.csv',
#  'mc_sim_1165_year_2017_risk_noise_20.csv',
#  'mc_sim_1166_year_2017_corr_noise_10.csv',
#  'mc_sim_1166_year_2017_ret_noise_50.csv',
#  'mc_sim_1166_year_2017_risk_noise_20.csv',
#  'mc_sim_1167_year_2017_corr_noise_10.csv',
#  'mc_sim_1167_year_2017_ret_noise_50.csv',
#  'mc_sim_1167_year_2017_risk_noise_20.csv',
#  'mc_sim_1168_year_2017_corr_noise_10.csv',
#  'mc_sim_1168_year_2017_ret_noise_50.csv',
#  'mc_sim_1168_year_2017_risk_noise_20.csv',
#  'mc_sim_1169_year_2017_corr_noise_10.csv',
#  'mc_sim_1169_year_2017_ret_noise_50.csv',
#  'mc_sim_1169_year_2017_risk_noise_20.csv',
#  'mc_sim_116_year_2017_corr_noise_10.csv',
#  'mc_sim_116_year_2017_ret_noise_20.csv',
#  'mc_sim_116_year_2017_risk_noise_10.csv',
#  'mc_sim_1170_year_2017_corr_noise_10.csv',
#  'mc_sim_1170_year_2017_ret_noise_50.csv',
#  'mc_sim_1170_year_2017_risk_noise_20.csv',
#  'mc_sim_1171_year_2017_corr_noise_10.csv',
#  'mc_sim_1171_year_2017_ret_noise_50.csv',
#  'mc_sim_1171_year_2017_risk_noise_20.csv',
#  'mc_sim_1172_year_2017_corr_noise_10.csv',
#  'mc_sim_1172_year_2017_ret_noise_50.csv',
#  'mc_sim_1172_year_2017_risk_noise_20.csv',
#  'mc_sim_1173_year_2017_corr_noise_10.csv',
#  'mc_sim_1173_year_2017_ret_noise_50.csv',
#  'mc_sim_1173_year_2017_risk_noise_20.csv',
#  'mc_sim_1174_year_2017_corr_noise_10.csv',
#  'mc_sim_1174_year_2017_ret_noise_50.csv',
#  'mc_sim_1174_year_2017_risk_noise_20.csv',
#  'mc_sim_1175_year_2017_corr_noise_10.csv',
#  'mc_sim_1175_year_2017_ret_noise_50.csv',
#  'mc_sim_1175_year_2017_risk_noise_20.csv',
#  'mc_sim_1176_year_2017_corr_noise_10.csv',
#  'mc_sim_1176_year_2017_ret_noise_50.csv',
#  'mc_sim_1176_year_2017_risk_noise_20.csv',
#  'mc_sim_1177_year_2017_corr_noise_10.csv',
#  'mc_sim_1177_year_2017_ret_noise_50.csv',
#  'mc_sim_1177_year_2017_risk_noise_20.csv',
#  'mc_sim_1178_year_2017_corr_noise_10.csv',
#  'mc_sim_1178_year_2017_ret_noise_50.csv',
#  'mc_sim_1178_year_2017_risk_noise_20.csv',
#  'mc_sim_1179_year_2017_corr_noise_10.csv',
#  'mc_sim_1179_year_2017_ret_noise_50.csv',
#  'mc_sim_1179_year_2017_risk_noise_20.csv',
#  'mc_sim_117_year_2017_corr_noise_10.csv',
#  'mc_sim_117_year_2017_ret_noise_20.csv',
#  'mc_sim_117_year_2017_risk_noise_10.csv',
#  'mc_sim_1180_year_2017_corr_noise_10.csv',
#  'mc_sim_1180_year_2017_ret_noise_50.csv',
#  'mc_sim_1180_year_2017_risk_noise_20.csv',
#  'mc_sim_1181_year_2017_corr_noise_10.csv',
#  'mc_sim_1181_year_2017_ret_noise_50.csv',
#  'mc_sim_1181_year_2017_risk_noise_20.csv',
#  'mc_sim_1182_year_2017_corr_noise_10.csv',
#  'mc_sim_1182_year_2017_ret_noise_50.csv',
#  'mc_sim_1182_year_2017_risk_noise_20.csv',
#  'mc_sim_1183_year_2017_corr_noise_10.csv',
#  'mc_sim_1183_year_2017_ret_noise_50.csv',
#  'mc_sim_1183_year_2017_risk_noise_20.csv',
#  'mc_sim_1184_year_2017_corr_noise_10.csv',
#  'mc_sim_1184_year_2017_ret_noise_50.csv',
#  'mc_sim_1184_year_2017_risk_noise_20.csv',
#  'mc_sim_1185_year_2017_corr_noise_10.csv',
#  'mc_sim_1185_year_2017_ret_noise_50.csv',
#  'mc_sim_1185_year_2017_risk_noise_20.csv',
#  'mc_sim_1186_year_2017_corr_noise_10.csv',
#  'mc_sim_1186_year_2017_ret_noise_50.csv',
#  'mc_sim_1186_year_2017_risk_noise_20.csv',
#  'mc_sim_1187_year_2017_corr_noise_10.csv',
#  'mc_sim_1187_year_2017_ret_noise_50.csv',
#  'mc_sim_1187_year_2017_risk_noise_20.csv',
#  'mc_sim_1188_year_2017_corr_noise_10.csv',
#  'mc_sim_1188_year_2017_ret_noise_50.csv',
#  'mc_sim_1188_year_2017_risk_noise_20.csv',
#  'mc_sim_1189_year_2017_corr_noise_10.csv',
#  'mc_sim_1189_year_2017_ret_noise_50.csv',
#  'mc_sim_1189_year_2017_risk_noise_20.csv',
#  'mc_sim_118_year_2017_corr_noise_10.csv',
#  'mc_sim_118_year_2017_ret_noise_20.csv',
#  'mc_sim_118_year_2017_risk_noise_10.csv',
#  'mc_sim_1190_year_2017_corr_noise_10.csv',
#  'mc_sim_1190_year_2017_ret_noise_50.csv',
#  'mc_sim_1190_year_2017_risk_noise_20.csv',
#  'mc_sim_1191_year_2017_corr_noise_10.csv',
#  'mc_sim_1191_year_2017_ret_noise_50.csv',
#  'mc_sim_1191_year_2017_risk_noise_20.csv',
#  'mc_sim_1192_year_2017_corr_noise_10.csv',
#  'mc_sim_1192_year_2017_ret_noise_50.csv',
#  'mc_sim_1192_year_2017_risk_noise_20.csv',
#  'mc_sim_1193_year_2017_corr_noise_10.csv',
#  'mc_sim_1193_year_2017_ret_noise_50.csv',
#  'mc_sim_1193_year_2017_risk_noise_20.csv',
#  'mc_sim_1194_year_2017_corr_noise_10.csv',
#  'mc_sim_1194_year_2017_ret_noise_50.csv',
#  'mc_sim_1194_year_2017_risk_noise_20.csv',
#  'mc_sim_1195_year_2017_corr_noise_10.csv',
#  'mc_sim_1195_year_2017_ret_noise_50.csv',
#  'mc_sim_1195_year_2017_risk_noise_20.csv',
#  'mc_sim_1196_year_2017_corr_noise_10.csv',
#  'mc_sim_1196_year_2017_ret_noise_50.csv',
#  'mc_sim_1196_year_2017_risk_noise_20.csv',
#  'mc_sim_1197_year_2017_corr_noise_10.csv',
#  'mc_sim_1197_year_2017_ret_noise_50.csv',
#  'mc_sim_1197_year_2017_risk_noise_20.csv',
#  'mc_sim_1198_year_2017_corr_noise_10.csv',
#  'mc_sim_1198_year_2017_ret_noise_50.csv',
#  'mc_sim_1198_year_2017_risk_noise_20.csv',
#  'mc_sim_1199_year_2017_corr_noise_10.csv',
#  'mc_sim_1199_year_2017_ret_noise_50.csv',
#  'mc_sim_1199_year_2017_risk_noise_20.csv',
#  'mc_sim_119_year_2017_corr_noise_10.csv',
#  'mc_sim_119_year_2017_ret_noise_20.csv',
#  'mc_sim_119_year_2017_risk_noise_10.csv',
#  'mc_sim_11_year_2017_corr_noise_5.csv',
#  'mc_sim_11_year_2017_ret_noise_20.csv',
#  'mc_sim_11_year_2017_risk_noise_10.csv',
#  'mc_sim_1200_year_2017_corr_noise_10.csv',
#  'mc_sim_1200_year_2017_ret_noise_50.csv',
#  'mc_sim_1200_year_2017_risk_noise_20.csv',
#  'mc_sim_1201_year_2018_corr_noise_5.csv',
#  'mc_sim_1201_year_2018_ret_noise_20.csv',
#  'mc_sim_1201_year_2018_risk_noise_10.csv',
#  'mc_sim_1202_year_2018_corr_noise_5.csv',
#  'mc_sim_1202_year_2018_ret_noise_20.csv',
#  'mc_sim_1202_year_2018_risk_noise_10.csv',
#  'mc_sim_1203_year_2018_corr_noise_5.csv',
#  'mc_sim_1203_year_2018_ret_noise_20.csv',
#  'mc_sim_1203_year_2018_risk_noise_10.csv',
#  'mc_sim_1204_year_2018_corr_noise_5.csv',
#  'mc_sim_1204_year_2018_ret_noise_20.csv',
#  'mc_sim_1204_year_2018_risk_noise_10.csv',
#  'mc_sim_1205_year_2018_corr_noise_5.csv',
#  'mc_sim_1205_year_2018_ret_noise_20.csv',
#  'mc_sim_1205_year_2018_risk_noise_10.csv',
#  'mc_sim_1206_year_2018_corr_noise_5.csv',
#  'mc_sim_1206_year_2018_ret_noise_20.csv',
#  'mc_sim_1206_year_2018_risk_noise_10.csv',
#  'mc_sim_1207_year_2018_corr_noise_5.csv',
#  'mc_sim_1207_year_2018_ret_noise_20.csv',
#  'mc_sim_1207_year_2018_risk_noise_10.csv',
#  'mc_sim_1208_year_2018_corr_noise_5.csv',
#  'mc_sim_1208_year_2018_ret_noise_20.csv',
#  'mc_sim_1208_year_2018_risk_noise_10.csv',
#  'mc_sim_1209_year_2018_corr_noise_5.csv',
#  'mc_sim_1209_year_2018_ret_noise_20.csv',
#  'mc_sim_1209_year_2018_risk_noise_10.csv',
#  'mc_sim_120_year_2017_corr_noise_10.csv',
#  'mc_sim_120_year_2017_ret_noise_20.csv',
#  'mc_sim_120_year_2017_risk_noise_10.csv',
#  'mc_sim_1210_year_2018_corr_noise_5.csv',
#  'mc_sim_1210_year_2018_ret_noise_20.csv',
#  'mc_sim_1210_year_2018_risk_noise_10.csv',
#  'mc_sim_1211_year_2018_corr_noise_5.csv',
#  'mc_sim_1211_year_2018_ret_noise_20.csv',
#  'mc_sim_1211_year_2018_risk_noise_10.csv',
#  'mc_sim_1212_year_2018_corr_noise_5.csv',
#  'mc_sim_1212_year_2018_ret_noise_20.csv',
#  'mc_sim_1212_year_2018_risk_noise_10.csv',
#  'mc_sim_1213_year_2018_corr_noise_5.csv',
#  'mc_sim_1213_year_2018_ret_noise_20.csv',
#  'mc_sim_1213_year_2018_risk_noise_10.csv',
#  'mc_sim_1214_year_2018_corr_noise_5.csv',
#  'mc_sim_1214_year_2018_ret_noise_20.csv',
#  'mc_sim_1214_year_2018_risk_noise_10.csv',
#  'mc_sim_1215_year_2018_corr_noise_5.csv',
#  'mc_sim_1215_year_2018_ret_noise_20.csv',
#  'mc_sim_1215_year_2018_risk_noise_10.csv',
#  'mc_sim_1216_year_2018_corr_noise_5.csv',
#  'mc_sim_1216_year_2018_ret_noise_20.csv',
#  'mc_sim_1216_year_2018_risk_noise_10.csv',
#  'mc_sim_1217_year_2018_corr_noise_5.csv',
#  'mc_sim_1217_year_2018_ret_noise_20.csv',
#  'mc_sim_1217_year_2018_risk_noise_10.csv',
#  'mc_sim_1218_year_2018_corr_noise_5.csv',
#  'mc_sim_1218_year_2018_ret_noise_20.csv',
#  'mc_sim_1218_year_2018_risk_noise_10.csv',
#  'mc_sim_1219_year_2018_corr_noise_5.csv',
#  'mc_sim_1219_year_2018_ret_noise_20.csv',
#  'mc_sim_1219_year_2018_risk_noise_10.csv',
#  'mc_sim_121_year_2017_corr_noise_10.csv',
#  'mc_sim_121_year_2017_ret_noise_20.csv',
#  'mc_sim_121_year_2017_risk_noise_10.csv',
#  'mc_sim_1220_year_2018_corr_noise_5.csv',
#  'mc_sim_1220_year_2018_ret_noise_20.csv',
#  'mc_sim_1220_year_2018_risk_noise_10.csv',
#  'mc_sim_1221_year_2018_corr_noise_5.csv',
#  'mc_sim_1221_year_2018_ret_noise_20.csv',
#  'mc_sim_1221_year_2018_risk_noise_10.csv',
#  'mc_sim_1222_year_2018_corr_noise_5.csv',
#  'mc_sim_1222_year_2018_ret_noise_20.csv',
#  'mc_sim_1222_year_2018_risk_noise_10.csv',
#  'mc_sim_1223_year_2018_corr_noise_5.csv',
#  'mc_sim_1223_year_2018_ret_noise_20.csv',
#  'mc_sim_1223_year_2018_risk_noise_10.csv',
#  'mc_sim_1224_year_2018_corr_noise_5.csv',
#  'mc_sim_1224_year_2018_ret_noise_20.csv',
#  'mc_sim_1224_year_2018_risk_noise_10.csv',
#  'mc_sim_1225_year_2018_corr_noise_5.csv',
#  'mc_sim_1225_year_2018_ret_noise_20.csv',
#  'mc_sim_1225_year_2018_risk_noise_10.csv',
#  'mc_sim_1226_year_2018_corr_noise_5.csv',
#  'mc_sim_1226_year_2018_ret_noise_20.csv',
#  'mc_sim_1226_year_2018_risk_noise_10.csv',
#  'mc_sim_1227_year_2018_corr_noise_5.csv',
#  'mc_sim_1227_year_2018_ret_noise_20.csv',
#  'mc_sim_1227_year_2018_risk_noise_10.csv',
#  'mc_sim_1228_year_2018_corr_noise_5.csv',
#  'mc_sim_1228_year_2018_ret_noise_20.csv',
#  'mc_sim_1228_year_2018_risk_noise_10.csv',
#  'mc_sim_1229_year_2018_corr_noise_5.csv',
#  'mc_sim_1229_year_2018_ret_noise_20.csv',
#  'mc_sim_1229_year_2018_risk_noise_10.csv',
#  'mc_sim_122_year_2017_corr_noise_10.csv',
#  'mc_sim_122_year_2017_ret_noise_20.csv',
#  'mc_sim_122_year_2017_risk_noise_10.csv',
#  'mc_sim_1230_year_2018_corr_noise_5.csv',
#  'mc_sim_1230_year_2018_ret_noise_20.csv',
#  'mc_sim_1230_year_2018_risk_noise_10.csv',
#  'mc_sim_1231_year_2018_corr_noise_5.csv',
#  'mc_sim_1231_year_2018_ret_noise_20.csv',
#  'mc_sim_1231_year_2018_risk_noise_10.csv',
#  'mc_sim_1232_year_2018_corr_noise_5.csv',
#  'mc_sim_1232_year_2018_ret_noise_20.csv',
#  'mc_sim_1232_year_2018_risk_noise_10.csv',
#  'mc_sim_1233_year_2018_corr_noise_5.csv',
#  'mc_sim_1233_year_2018_ret_noise_20.csv',
#  'mc_sim_1233_year_2018_risk_noise_10.csv',
#  'mc_sim_1234_year_2018_corr_noise_5.csv',
#  'mc_sim_1234_year_2018_ret_noise_20.csv',
#  'mc_sim_1234_year_2018_risk_noise_10.csv',
#  'mc_sim_1235_year_2018_corr_noise_5.csv',
#  'mc_sim_1235_year_2018_ret_noise_20.csv',
#  'mc_sim_1235_year_2018_risk_noise_10.csv',
#  'mc_sim_1236_year_2018_corr_noise_5.csv',
#  'mc_sim_1236_year_2018_ret_noise_20.csv',
#  'mc_sim_1236_year_2018_risk_noise_10.csv',
#  'mc_sim_1237_year_2018_corr_noise_5.csv',
#  'mc_sim_1237_year_2018_ret_noise_20.csv',
#  'mc_sim_1237_year_2018_risk_noise_10.csv',
#  'mc_sim_1238_year_2018_corr_noise_5.csv',
#  'mc_sim_1238_year_2018_ret_noise_20.csv',
#  'mc_sim_1238_year_2018_risk_noise_10.csv',
#  'mc_sim_1239_year_2018_corr_noise_5.csv',
#  'mc_sim_1239_year_2018_ret_noise_20.csv',
#  'mc_sim_1239_year_2018_risk_noise_10.csv',
#  'mc_sim_123_year_2017_corr_noise_10.csv',
#  'mc_sim_123_year_2017_ret_noise_20.csv',
#  'mc_sim_123_year_2017_risk_noise_10.csv',
#  'mc_sim_1240_year_2018_corr_noise_5.csv',
#  'mc_sim_1240_year_2018_ret_noise_20.csv',
#  'mc_sim_1240_year_2018_risk_noise_10.csv',
#  'mc_sim_1241_year_2018_corr_noise_5.csv',
#  'mc_sim_1241_year_2018_ret_noise_20.csv',
#  'mc_sim_1241_year_2018_risk_noise_10.csv',
#  'mc_sim_1242_year_2018_corr_noise_5.csv',
#  'mc_sim_1242_year_2018_ret_noise_20.csv',
#  'mc_sim_1242_year_2018_risk_noise_10.csv',
#  'mc_sim_1243_year_2018_corr_noise_5.csv',
#  'mc_sim_1243_year_2018_ret_noise_20.csv',
#  'mc_sim_1243_year_2018_risk_noise_10.csv',
#  'mc_sim_1244_year_2018_corr_noise_5.csv',
#  'mc_sim_1244_year_2018_ret_noise_20.csv',
#  'mc_sim_1244_year_2018_risk_noise_10.csv',
#  'mc_sim_1245_year_2018_corr_noise_5.csv',
#  'mc_sim_1245_year_2018_ret_noise_20.csv',
#  'mc_sim_1245_year_2018_risk_noise_10.csv',
#  'mc_sim_1246_year_2018_corr_noise_5.csv',
#  'mc_sim_1246_year_2018_ret_noise_20.csv',
#  'mc_sim_1246_year_2018_risk_noise_10.csv',
#  'mc_sim_1247_year_2018_corr_noise_5.csv',
#  'mc_sim_1247_year_2018_ret_noise_20.csv',
#  'mc_sim_1247_year_2018_risk_noise_10.csv',
#  'mc_sim_1248_year_2018_corr_noise_5.csv',
#  'mc_sim_1248_year_2018_ret_noise_20.csv',
#  'mc_sim_1248_year_2018_risk_noise_10.csv',
#  'mc_sim_1249_year_2018_corr_noise_5.csv',
#  'mc_sim_1249_year_2018_ret_noise_20.csv',
#  'mc_sim_1249_year_2018_risk_noise_10.csv',
#  'mc_sim_124_year_2017_corr_noise_10.csv',
#  'mc_sim_124_year_2017_ret_noise_20.csv',
#  'mc_sim_124_year_2017_risk_noise_10.csv',
#  'mc_sim_1250_year_2018_corr_noise_5.csv',
#  'mc_sim_1250_year_2018_ret_noise_20.csv',
#  'mc_sim_1250_year_2018_risk_noise_10.csv',
#  'mc_sim_1251_year_2018_corr_noise_5.csv',
#  'mc_sim_1251_year_2018_ret_noise_20.csv',
#  'mc_sim_1251_year_2018_risk_noise_10.csv',
#  'mc_sim_1252_year_2018_corr_noise_5.csv',
#  'mc_sim_1252_year_2018_ret_noise_20.csv',
#  'mc_sim_1252_year_2018_risk_noise_10.csv',
#  'mc_sim_1253_year_2018_corr_noise_5.csv',
#  'mc_sim_1253_year_2018_ret_noise_20.csv',
#  'mc_sim_1253_year_2018_risk_noise_10.csv',
#  'mc_sim_1254_year_2018_corr_noise_5.csv',
#  'mc_sim_1254_year_2018_ret_noise_20.csv',
#  'mc_sim_1254_year_2018_risk_noise_10.csv',
#  'mc_sim_1255_year_2018_corr_noise_5.csv',
#  'mc_sim_1255_year_2018_ret_noise_20.csv',
#  'mc_sim_1255_year_2018_risk_noise_10.csv',
#  'mc_sim_1256_year_2018_corr_noise_5.csv',
#  'mc_sim_1256_year_2018_ret_noise_20.csv',
#  'mc_sim_1256_year_2018_risk_noise_10.csv',
#  'mc_sim_1257_year_2018_corr_noise_5.csv',
#  'mc_sim_1257_year_2018_ret_noise_20.csv',
#  'mc_sim_1257_year_2018_risk_noise_10.csv',
#  'mc_sim_1258_year_2018_corr_noise_5.csv',
#  'mc_sim_1258_year_2018_ret_noise_20.csv',
#  'mc_sim_1258_year_2018_risk_noise_10.csv',
#  'mc_sim_1259_year_2018_corr_noise_5.csv',
#  'mc_sim_1259_year_2018_ret_noise_20.csv',
#  'mc_sim_1259_year_2018_risk_noise_10.csv',
#  'mc_sim_125_year_2017_corr_noise_10.csv',
#  'mc_sim_125_year_2017_ret_noise_20.csv',
#  'mc_sim_125_year_2017_risk_noise_10.csv',
#  'mc_sim_1260_year_2018_corr_noise_5.csv',
#  'mc_sim_1260_year_2018_ret_noise_20.csv',
#  'mc_sim_1260_year_2018_risk_noise_10.csv',
#  'mc_sim_1261_year_2018_corr_noise_5.csv',
#  'mc_sim_1261_year_2018_ret_noise_20.csv',
#  'mc_sim_1261_year_2018_risk_noise_10.csv',
#  'mc_sim_1262_year_2018_corr_noise_5.csv',
#  'mc_sim_1262_year_2018_ret_noise_20.csv',
#  'mc_sim_1262_year_2018_risk_noise_10.csv',
#  'mc_sim_1263_year_2018_corr_noise_5.csv',
#  'mc_sim_1263_year_2018_ret_noise_20.csv',
#  'mc_sim_1263_year_2018_risk_noise_10.csv',
#  'mc_sim_1264_year_2018_corr_noise_5.csv',
#  'mc_sim_1264_year_2018_ret_noise_20.csv',
#  'mc_sim_1264_year_2018_risk_noise_10.csv',
#  'mc_sim_1265_year_2018_corr_noise_5.csv',
#  'mc_sim_1265_year_2018_ret_noise_20.csv',
#  'mc_sim_1265_year_2018_risk_noise_10.csv',
#  'mc_sim_1266_year_2018_corr_noise_5.csv',
#  'mc_sim_1266_year_2018_ret_noise_20.csv',
#  'mc_sim_1266_year_2018_risk_noise_10.csv',
#  'mc_sim_1267_year_2018_corr_noise_5.csv',
#  'mc_sim_1267_year_2018_ret_noise_20.csv',
#  'mc_sim_1267_year_2018_risk_noise_10.csv',
#  'mc_sim_1268_year_2018_corr_noise_5.csv',
#  'mc_sim_1268_year_2018_ret_noise_20.csv',
#  'mc_sim_1268_year_2018_risk_noise_10.csv',
#  'mc_sim_1269_year_2018_corr_noise_5.csv',
#  'mc_sim_1269_year_2018_ret_noise_20.csv',
#  'mc_sim_1269_year_2018_risk_noise_10.csv',
#  'mc_sim_126_year_2017_corr_noise_10.csv',
#  'mc_sim_126_year_2017_ret_noise_20.csv',
#  'mc_sim_126_year_2017_risk_noise_10.csv',
#  'mc_sim_1270_year_2018_corr_noise_5.csv',
#  'mc_sim_1270_year_2018_ret_noise_20.csv',
#  'mc_sim_1270_year_2018_risk_noise_10.csv',
#  'mc_sim_1271_year_2018_corr_noise_5.csv',
#  'mc_sim_1271_year_2018_ret_noise_20.csv',
#  'mc_sim_1271_year_2018_risk_noise_10.csv',
#  'mc_sim_1272_year_2018_corr_noise_5.csv',
#  'mc_sim_1272_year_2018_ret_noise_20.csv',
#  'mc_sim_1272_year_2018_risk_noise_10.csv',
#  'mc_sim_1273_year_2018_corr_noise_5.csv',
#  'mc_sim_1273_year_2018_ret_noise_20.csv',
#  'mc_sim_1273_year_2018_risk_noise_10.csv',
#  'mc_sim_1274_year_2018_corr_noise_5.csv',
#  'mc_sim_1274_year_2018_ret_noise_20.csv',
#  'mc_sim_1274_year_2018_risk_noise_10.csv',
#  'mc_sim_1275_year_2018_corr_noise_5.csv',
#  'mc_sim_1275_year_2018_ret_noise_20.csv',
#  'mc_sim_1275_year_2018_risk_noise_10.csv',
#  'mc_sim_1276_year_2018_corr_noise_5.csv',
#  'mc_sim_1276_year_2018_ret_noise_20.csv',
#  'mc_sim_1276_year_2018_risk_noise_10.csv',
#  'mc_sim_1277_year_2018_corr_noise_5.csv',
#  'mc_sim_1277_year_2018_ret_noise_20.csv',
#  'mc_sim_1277_year_2018_risk_noise_10.csv',
#  'mc_sim_1278_year_2018_corr_noise_5.csv',
#  'mc_sim_1278_year_2018_ret_noise_20.csv',
#  'mc_sim_1278_year_2018_risk_noise_10.csv',
#  'mc_sim_1279_year_2018_corr_noise_5.csv',
#  'mc_sim_1279_year_2018_ret_noise_20.csv',
#  'mc_sim_1279_year_2018_risk_noise_10.csv',
#  'mc_sim_127_year_2017_corr_noise_10.csv',
#  'mc_sim_127_year_2017_ret_noise_20.csv',
#  'mc_sim_127_year_2017_risk_noise_10.csv',
#  'mc_sim_1280_year_2018_corr_noise_5.csv',
#  'mc_sim_1280_year_2018_ret_noise_20.csv',
#  'mc_sim_1280_year_2018_risk_noise_10.csv',
#  'mc_sim_1281_year_2018_corr_noise_5.csv',
#  'mc_sim_1281_year_2018_ret_noise_20.csv',
#  'mc_sim_1281_year_2018_risk_noise_10.csv',
#  'mc_sim_1282_year_2018_corr_noise_5.csv',
#  'mc_sim_1282_year_2018_ret_noise_20.csv',
#  'mc_sim_1282_year_2018_risk_noise_10.csv',
#  'mc_sim_1283_year_2018_corr_noise_5.csv',
#  'mc_sim_1283_year_2018_ret_noise_20.csv',
#  'mc_sim_1283_year_2018_risk_noise_10.csv',
#  'mc_sim_1284_year_2018_corr_noise_5.csv',
#  'mc_sim_1284_year_2018_ret_noise_20.csv',
#  'mc_sim_1284_year_2018_risk_noise_10.csv',
#  'mc_sim_1285_year_2018_corr_noise_5.csv',
#  'mc_sim_1285_year_2018_ret_noise_20.csv',
#  'mc_sim_1285_year_2018_risk_noise_10.csv',
#  'mc_sim_1286_year_2018_corr_noise_5.csv',
#  'mc_sim_1286_year_2018_ret_noise_20.csv',
#  'mc_sim_1286_year_2018_risk_noise_10.csv',
#  'mc_sim_1287_year_2018_corr_noise_5.csv',
#  'mc_sim_1287_year_2018_ret_noise_20.csv',
#  'mc_sim_1287_year_2018_risk_noise_10.csv',
#  'mc_sim_1288_year_2018_corr_noise_5.csv',
#  'mc_sim_1288_year_2018_ret_noise_20.csv',
#  'mc_sim_1288_year_2018_risk_noise_10.csv',
#  'mc_sim_1289_year_2018_corr_noise_5.csv',
#  'mc_sim_1289_year_2018_ret_noise_20.csv',
#  'mc_sim_1289_year_2018_risk_noise_10.csv',
#  'mc_sim_128_year_2017_corr_noise_10.csv',
#  'mc_sim_128_year_2017_ret_noise_20.csv',
#  'mc_sim_128_year_2017_risk_noise_10.csv',
#  'mc_sim_1290_year_2018_corr_noise_5.csv',
#  'mc_sim_1290_year_2018_ret_noise_20.csv',
#  'mc_sim_1290_year_2018_risk_noise_10.csv',
#  'mc_sim_1291_year_2018_corr_noise_5.csv',
#  'mc_sim_1291_year_2018_ret_noise_20.csv',
#  'mc_sim_1291_year_2018_risk_noise_10.csv',
#  'mc_sim_1292_year_2018_corr_noise_5.csv',
#  'mc_sim_1292_year_2018_ret_noise_20.csv',
#  'mc_sim_1292_year_2018_risk_noise_10.csv',
#  'mc_sim_1293_year_2018_corr_noise_5.csv',
#  'mc_sim_1293_year_2018_ret_noise_20.csv',
#  'mc_sim_1293_year_2018_risk_noise_10.csv',
#  'mc_sim_1294_year_2018_corr_noise_5.csv',
#  'mc_sim_1294_year_2018_ret_noise_20.csv',
#  'mc_sim_1294_year_2018_risk_noise_10.csv',
#  'mc_sim_1295_year_2018_corr_noise_5.csv',
#  'mc_sim_1295_year_2018_ret_noise_20.csv',
#  'mc_sim_1295_year_2018_risk_noise_10.csv',
#  'mc_sim_1296_year_2018_corr_noise_5.csv',
#  'mc_sim_1296_year_2018_ret_noise_20.csv',
#  'mc_sim_1296_year_2018_risk_noise_10.csv',
#  'mc_sim_1297_year_2018_corr_noise_5.csv',
#  'mc_sim_1297_year_2018_ret_noise_20.csv',
#  'mc_sim_1297_year_2018_risk_noise_10.csv',
#  'mc_sim_1298_year_2018_corr_noise_5.csv',
#  'mc_sim_1298_year_2018_ret_noise_20.csv',
#  'mc_sim_1298_year_2018_risk_noise_10.csv',
#  'mc_sim_1299_year_2018_corr_noise_5.csv',
#  'mc_sim_1299_year_2018_ret_noise_20.csv',
#  'mc_sim_1299_year_2018_risk_noise_10.csv',
#  'mc_sim_129_year_2017_corr_noise_10.csv',
#  'mc_sim_129_year_2017_ret_noise_20.csv',
#  'mc_sim_129_year_2017_risk_noise_10.csv',
#  'mc_sim_12_year_2017_corr_noise_5.csv',
#  'mc_sim_12_year_2017_ret_noise_20.csv',
#  'mc_sim_12_year_2017_risk_noise_10.csv',
#  'mc_sim_1300_year_2018_corr_noise_5.csv',
#  ...]

# %%
tt= file_names[0]
tt
# Out:
# 'mc_sim_1000_year_2017_corr_noise_10.csv'

# %%
tt=tt.split('.')[:-1][0].split('_')

# %%
total_n = 25
k = 3
num_pf_wt_generations = 100000  # I want to restrict this number so that the final size of files is 
                                   # computationally tractable. Try num_gen = 1 lakh or 50K for n = 3
    
pf_wts_list = gen_pf_wts(total_n, k, num_pf_wt_generations)

for sim_num in tqdm(range(1,8400, 24)):
    filter_files = [x for x in file_names if 'mc_sim_'+str(sim_num)+'_' in x]    
    ret_fname = [x for x in filter_files if 'ret_noise' in x][0]
    risk_fname = [x for x in filter_files if 'risk_noise' in x][0]
    corr_fname = [x for x in filter_files if 'corr_noise' in x][0]

    annual_ret = pd.read_csv(sim_save_dir+'//'+ret_fname, header=None)
    annual_ret.columns = ['mf_id','annual_return']
    annual_vol = pd.read_csv(sim_save_dir+'//'+risk_fname, header=None)
    annual_vol.columns = ['mf_id','annual_vol']
    annual_corr = pd.read_csv(sim_save_dir+'//'+corr_fname, index_col=0)
    ret_np = np.array(annual_ret['annual_return'])
    vol_np = np.array(annual_vol['annual_vol'])
    corr_np = np.array(annual_corr)
    tt=ret_fname.split('.')[:-1][0].split('_')
    new_fname = 'mc_sim_' + str(tt[2])
    tyear = str(tt[4])
    
    for pf_wts in pf_wts_list:
        portfolio_return, portfolio_vol = generate_portfolio_ret_vol(pf_wts, ret_np, vol_np, corr_np)
        write_results_to_csv(new_fname, tyear,  pf_wts, portfolio_return, portfolio_vol)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 350/350 [2:07:13<00:00, 21.81s/it]
