# %% [markdown]
# #### Use this Code to download historical data for Indian Market benchmarks

# %%
import yfinance as yf

# Download Nifty 50 data
df = yf.download(['^NSEI', '^BSESN', '^CRSLDX','^NSEMDCP50'],  start='2016-12-31', end='2024-05-01')[['Adj Close']]
# Out:
# [*********************100%***********************]  4 of 4 completed

# %% [markdown]
# Index	Description	Yahoo Finance Ticker
#
# Nifty 50	Top 50 companies on NSE	^NSEI
#
# BSE Sensex	Top 30 companies on BSE	^BSESN
#
# Nifty Midcap 50	Top 50 mid-cap companies on NSE	^NSEMDCP50
#
# Nifty 500 ^CRSLDX

# %%
df.to_csv(r'../data/market_benchmarks_historical_data/benchmark_data.csv')

# %%
df
# Out:
# Price                         Adj Close                              \
# Ticker                           ^BSESN       ^CRSLDX         ^NSEI
# Date
# 2017-01-02 00:00:00+00:00  26595.449219   7002.490723   8179.500000
# 2017-01-03 00:00:00+00:00  26643.240234   7028.740723   8192.250000
# 2017-01-04 00:00:00+00:00  26633.130859   7030.740723   8190.500000
# 2017-01-05 00:00:00+00:00  26878.240234   7106.890625   8273.799805
# 2017-01-06 00:00:00+00:00  26759.230469   7083.090820   8243.799805
# ...                                 ...           ...           ...
# 2024-04-24 00:00:00+00:00  73852.937500  20730.650391  22402.400391
# 2024-04-25 00:00:00+00:00  74339.437500  20867.900391  22570.349609
# 2024-04-26 00:00:00+00:00  73730.156250  20839.349609  22419.949219
# 2024-04-29 00:00:00+00:00  74671.281250  20992.199219  22643.400391
# 2024-04-30 00:00:00+00:00  74482.781250  20997.199219  22604.849609
#
# Price
# Ticker                       ^NSEMDCP50
# Date
# ...

# %%
# !pip install yfinance
# Out:
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# ...
#      ---------------------------------------- 0.0/939.5 kB ? eta -:--:--
#      ---------------------------------------- 10.2/939.5 kB ? eta -:--:--
#      - ----------------------------------- 41.0/939.5 kB 653.6 kB/s eta 0:00:02
#      -- ---------------------------------- 71.7/939.5 kB 653.6 kB/s eta 0:00:02
#      ---- ------------------------------- 112.6/939.5 kB 726.2 kB/s eta 0:00:02
#      ----- ------------------------------ 143.4/939.5 kB 655.8 kB/s eta 0:00:02
#      ------ ----------------------------- 174.1/939.5 kB 615.9 kB/s eta 0:00:02
#      -------- --------------------------- 225.3/939.5 kB 687.0 kB/s eta 0:00:02
#      --------- -------------------------- 256.0/939.5 kB 714.4 kB/s eta 0:00:01
#      ---------- ------------------------- 276.5/939.5 kB 710.0 kB/s eta 0:00:01
#      ------------ ----------------------- 317.4/939.5 kB 678.1 kB/s eta 0:00:01
# ...
